# %%
# API
# Web Scraping
# Database(MYSQL)

# %% [markdown]
# ### to connect python code with database

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Users/sonupanchal/anaconda3/lib/python3.11/site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in /Users/sonupanchal/anaconda3/lib/python3.11/site-packages (from mysql-connector-python) (4.21.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %% [markdown]
# ### start mamp server, change the port number -> connet with phpmyadmin

# %%
config = {
  'user': 'root',
  'password': 'root',
  'host': 'localhost',
  'unix_socket': '/Applications/MAMP/tmp/mysql/mysql.sock',
  'database': 'flaskloginDB',
  'raise_on_warnings': True
}

cnx = mysql.connector.connect(**config)

# %%
cursor = cnx.cursor(dictionary=True)

cursor.execute('SELECT * FROM `users`')

results = cursor.fetchall()

# %%
results
# Out:
# [{'user_id': 123, 'name': 'sonu', 'email': 'sonu@gmail.com', 'password': 123},
#  {'user_id': 124, 'name': 'arya', 'email': 'arya@gmail.com', 'password': 124},
#  {'user_id': 125,
#   'name': 'Khaleesi',
#   'email': 'Khaleesi@gmail.com',
#   'password': 123},
#  {'user_id': 126, 'name': 'xyz', 'email': 'xyz@gmail.com', 'password': 123},
#  {'user_id': 127, 'name': 'john', 'email': 'john@gmail.com', 'password': 567}]
